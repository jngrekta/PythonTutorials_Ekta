# %% [markdown]
# # **Choose meaningful variable names for the following questions:**
# ---
#
# ## 1. Imagine you have a list of student names. What variable name would you choose for this list?
# ## 2. Suppose you have a list of temperatures recorded throughout the day. How would you name this list?
# ## 3. Consider a list containing the prices of various products. What variable name would you give to this list?
# ## 4. You have a list of book titles. How would you name the variable holding this data?
# ## 5. Imagine you have a list of employee ages. What variable name would you use to represent this list?
# ## 6. Suppose you have a list of cities visited during a trip. What variable name would you choose for this list?

# %% [markdown]
# # **Questions on Operators:**
# ---
#
# ## 1. What is the result of 5 + 3?
# ## 2. What is the value of 8 - 4 * 2?
# ## 3. Calculate the remainder of 15 divided by 4.
# ## 4. Write an expression to check if a number is even.
# ## 5. Given the variables x = 10 and y = 3, what is the value of x // y?
# ## 6. Create an expression to check if a number is positive.
# ## 7. What is the result of 3 ** 4?
# ## 8. Given the variables a = 7 and b = 2, what is the value of a % b?
# ## 9. Write an expression to check if a number is divisible by both 3 and 5.
# ## 10. Given the variables p = 4 and q = 2, what is the value of p ** q?

# %% [markdown]
# # **Questions on Conditional Statements (if, if-else, if-elif-else, etc.):**
# ---
#
# ## 1. Write a program that checks if a given number is positive, negative, or zero.
#
# ## 2. Write a program that determines the largest of three given numbers.
# ## 3. Write a program that checks if a given string is a palindrome. Ex: 'MADAM'
#
# ## 4. Write a program that converts a given temperature in Celsius to Fahrenheit or vice versa based on user input.
# * Formulas:
#   * fahrenheit = (celsius * 9/5) + 32
#   * celsius = (fahrenheit - 32) * 5/9

# %% [markdown]
# # **Questions on Loops:**
# ---
#
# ## 1. Write a program that prints the multiplication table of a given number using a for loop.
#
# ## 2. Write a program that prints the uppercase letters of the alphabet using a for loop.
#
# ## 3. Write a program that calculates the factorial of a given number using a while loop.

# %% [markdown]
# ## 4. Print the following pattern using nested loop.

# %%
"""
*****
****
***
**
*
"""

# %% [markdown]
# ## 5. Print the following pattern using nested loop.

# %%
"""
1
22
333
4444
55555
"""

# %% [markdown]
# ## 6. Print the following pattern using nested loop.

# %%
"""
    A
   BB
  CCC
 DDDD
EEEEE
"""
